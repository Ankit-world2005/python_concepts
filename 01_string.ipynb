# %%
name = "ankit singh"

# %%
name
# Out:
# 'ankitsingh'

# %%
name.upper()
# Out:
# 'ANKITSINGH'

# %%
name.endswith("it")
# Out:
# False

# %%
name.count("n")
# Out:
# 2

# %%
 print(len(name))
# Out:
# 10

# %%
name.strip() #strip remove the spaces from the strings
# Out:
# 'ankitsingh'

# %%
name.replace('ankit','singh')
# Out:
# 'singhsingh'

# %%
print(name.split(","))
# Out:
# ['ankitsingh']

# %%
 name[0:2] #indexing
# Out:
# 'an'

# %%
name[:-1]
# Out:
# 'ankitsing'

# %%
name[0:5]
# Out:
# 'ankit'

# %%
name.isalpha()
# Out:
# True

# %%
name.isalnum()
# Out:
# True

# %%
name.isdigit()
# Out:
# False

# %%
print(f"my name is {name}")
# Out:
# my name is ankitsingh

# %%
def sum(a,b):
    print(a+b)
    return
sum(2,3)
# Out:
# 5

# %%
# define recursion using function
def fact(n=0):
    if n==0 or n==1: #base case of recursion 
        return 1
    return fact(n-1)*n
fact(5)
# Out:
# 120
