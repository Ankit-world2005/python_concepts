# %% [raw]
# # python follows pemdas rule
# # where pemdas stands for:- (parenthesis ,exponent,multiplication,division,addition,subtraction)

# %%
a =int(input())
b = int(input())
c = int(input())
d = int(input())
# Out:
#  8
#  5
#  2
#  4

# %%
print((a+c)/d-(a+b))
# Out:
# -10.5

# %%
#arithematic precedence

print(10 + 5 * 2)       
print((10 + 5) * 2)     
print(2 ** 3 ** 2)
# Out:
# 20
# 30
# 512

# %%
#logical precedence

print(3 < 5 and 5 < 10)  
print(True or False and False)  
print(not True or False)
# Out:
# True
# True
# False

# %%
#mixed precedence


x = 10
y = 5
print(x + y * 2 < 25 and not (x == y))
# Out:
# True
