# %%
a = input("enter the number")
print(a)
# Out:
# enter the number ankit
# ankit

# %%
num1 = input("enter the number:")
# Out:
# enter the number: 42

# %%
num2 = input("enter the number:")
# Out:
# enter the number: 43

# %%
int(num1) + int(num2)
# Out:
# 85
