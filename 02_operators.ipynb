# %%
                                                            #python operator

# %%
a = 11
b = 2

# %%
a+b #additon operator
# Out:
# 13

# %%
a-b #subtractive operater
# Out:
# 9

# %%
a*b #multiplicative operator
# Out:
# 22

# %%
a/b
# Out:
# 5.5

# %%
a//b
# Out:
# 5

# %%
a%b #modulous operator
# Out:
# 1

# %%
a != b #negation operator or boolean operator
# Out:
# True

# %%
a > b #comparison operator
# Out:
# True

# %%
a<b
# Out:
# False
